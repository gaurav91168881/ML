# %%
import numpy as np

# %%
def gradient_descent(x,y):  # `x` -> Feature | `y` - Target
    m = 0  # Initial Value of `m`
    c = 0  # Initial Value of `c`
    learning_rate = 0.05  # Arbitary Value for alpha
    n = len(x)  # number of rows | sample size
    no_of_steps = 1000  # Iterations

    for step_no in range(no_of_steps):
        y_pred = m * x + c
        cost = (1/n) * sum([val ** 2 for val in (y - y_pred)])

        dm = (-2/n) * sum(x * (y - y_pred))
        dc = (-2/n) * sum(y - y_pred)

        m = m - learning_rate * dm  # move towards downward dxn to find minima
        c = c - learning_rate * dc  # move towards downward dxn to find minima

        print(f"Step No. = {step_no + 1} | Slope = {round(m,2)} | Intercept = {round(c,2)} | Cost = {round(cost,2)}")

# %%
x = np.array([1,2,3,4,5])  # Feature
y = np.array([3,13,11,7,25])  # Target

# %%
gradient_descent(x,y)
# Out:
# Step No. = 1 | Slope = 11.29 | Intercept = 3.08 | Cost = 1158.35
# Step No. = 2 | Slope = 9.24 | Intercept = 2.46 | Cost = 40.04
# Step No. = 3 | Slope = 9.63 | Intercept = 2.52 | Cost = 2.51
# Step No. = 4 | Slope = 9.57 | Intercept = 2.46 | Cost = 1.21
# Step No. = 5 | Slope = 9.59 | Intercept = 2.42 | Cost = 1.13
# Step No. = 6 | Slope = 9.6 | Intercept = 2.38 | Cost = 1.09
# Step No. = 7 | Slope = 9.61 | Intercept = 2.34 | Cost = 1.06
# Step No. = 8 | Slope = 9.62 | Intercept = 2.3 | Cost = 1.02
# Step No. = 9 | Slope = 9.64 | Intercept = 2.26 | Cost = 0.99
# Step No. = 10 | Slope = 9.65 | Intercept = 2.22 | Cost = 0.95
# Step No. = 11 | Slope = 9.66 | Intercept = 2.18 | Cost = 0.92
# Step No. = 12 | Slope = 9.67 | Intercept = 2.15 | Cost = 0.89
# Step No. = 13 | Slope = 9.68 | Intercept = 2.11 | Cost = 0.86
# Step No. = 14 | Slope = 9.69 | Intercept = 2.07 | Cost = 0.83
# Step No. = 15 | Slope = 9.7 | Intercept = 2.04 | Cost = 0.8
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)

# %%
plt.scatter(x,y)
plt.plot(x, 3.8 * x + 0.4, color = 'red')

# %% [markdown]
# ### Lets test the Algorithm
# by giving the data as exact output of the function `y_pred = 10.27 * x - 0.03`

# %%
x = np.array([1,2,3,4,5])  # Feature
print(10.27*x - 0.03)
# Out:
# [10.24 20.51 30.78 41.05 51.32]

# %%
x = np.array([1,2,3,4,5])  # Feature
y = np.array([10.24, 20.51, 30.78, 41.05, 51.32])  # Target - calculated from above formula

# %%
plt.scatter(x,y)  # since y is calc using the formulae itself, hence the dots are allinged perfectly

# %%
gradient_descent(x,y) # the output should be the same equation that we used to generate the values of `y`
# Out:
# Step No. = 1 | Slope = 11.29 | Intercept = 3.08 | Cost = 1158.35
# Step No. = 2 | Slope = 9.24 | Intercept = 2.46 | Cost = 40.04
# Step No. = 3 | Slope = 9.63 | Intercept = 2.52 | Cost = 2.51
# Step No. = 4 | Slope = 9.57 | Intercept = 2.46 | Cost = 1.21
# Step No. = 5 | Slope = 9.59 | Intercept = 2.42 | Cost = 1.13
# Step No. = 6 | Slope = 9.6 | Intercept = 2.38 | Cost = 1.09
# Step No. = 7 | Slope = 9.61 | Intercept = 2.34 | Cost = 1.06
# Step No. = 8 | Slope = 9.62 | Intercept = 2.3 | Cost = 1.02
# Step No. = 9 | Slope = 9.64 | Intercept = 2.26 | Cost = 0.99
# Step No. = 10 | Slope = 9.65 | Intercept = 2.22 | Cost = 0.95
# Step No. = 11 | Slope = 9.66 | Intercept = 2.18 | Cost = 0.92
# Step No. = 12 | Slope = 9.67 | Intercept = 2.15 | Cost = 0.89
# Step No. = 13 | Slope = 9.68 | Intercept = 2.11 | Cost = 0.86
# Step No. = 14 | Slope = 9.69 | Intercept = 2.07 | Cost = 0.83
# Step No. = 15 | Slope = 9.7 | Intercept = 2.04 | Cost = 0.8
# ...

# %%
plt.scatter(x,y)
plt.plot(x, 10.27 * x - 0.03, color = 'red')
